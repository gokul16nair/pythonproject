# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:/Datasets/Online_Retail.csv")
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
data = pd.read_csv("D:/Datasets/Online_Retail.csv",parse_dates=["InvoiceDate"]) ## to convert dates in to yyyy/mm/dd format
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
data["Description"]=data["Description"].fillna("null")
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
print("date from",data.InvoiceDate.min(),"to",data.InvoiceDate.max())
# Out:
# date from 2010-12-01 08:26:00 to 2011-12-09 12:50:00

# %%
data["Description"]
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
data['Description'] = data['Description'].astype(str)

# %%
# data

# %%
data["year"] = data["InvoiceDate"].dt.year
data["month"]=data["InvoiceDate"].dt.month
data["day"]=data["InvoiceDate"].dt.day
data["day-week"]=data["InvoiceDate"].dt.day_name()

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  year  \
# ...

# %%
data_new = pd.DataFrame(data.groupby("InvoiceDate")["Description"].nunique().index) ## To arrange by ascending order date
data_new
# Out:
#               InvoiceDate
# 0     2010-12-01 08:26:00
# 1     2010-12-01 08:28:00
# 2     2010-12-01 08:34:00
# 3     2010-12-01 08:35:00
# 4     2010-12-01 08:45:00
# ...                   ...
# 23255 2011-12-09 12:23:00
# 23256 2011-12-09 12:25:00
# 23257 2011-12-09 12:31:00
# 23258 2011-12-09 12:49:00
# 23259 2011-12-09 12:50:00
#
# [23260 rows x 1 columns]

# %%
data_new["member_count"]=data.groupby("InvoiceDate")["CustomerID"].nunique().values ## show member count
data_new["Items_count"]=data.groupby("InvoiceDate")["Description"].nunique().values ## number count
data_new["Items"]=data.groupby("InvoiceDate")["Description"].unique().values ## List not number
data_new
# Out:
#               InvoiceDate  member_count  Items_count  \
# 0     2010-12-01 08:26:00             1            7
# 1     2010-12-01 08:28:00             1            2
# 2     2010-12-01 08:34:00             1           16
# 3     2010-12-01 08:35:00             1            1
# 4     2010-12-01 08:45:00             1           20
# ...                   ...           ...          ...
# 23255 2011-12-09 12:23:00             1            2
# 23256 2011-12-09 12:25:00             1            2
# 23257 2011-12-09 12:31:00             1           21
# 23258 2011-12-09 12:49:00             1            4
# 23259 2011-12-09 12:50:00             1           15
#
#                                                    Items
# 0      [WHITE HANGING HEART T-LIGHT HOLDER, WHITE MET...
# 1      [HAND WARMER UNION JACK, HAND WARMER RED POLKA...
# 2      [ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHO...
# 3                             [BATH BUILDING BLOCK WORD]
# ...

# %%
data_new.set_index("InvoiceDate",inplace=True)
data_new
# Out:
#                      member_count  Items_count  \
# InvoiceDate
# 2010-12-01 08:26:00             1            7
# 2010-12-01 08:28:00             1            2
# 2010-12-01 08:34:00             1           16
# 2010-12-01 08:35:00             1            1
# 2010-12-01 08:45:00             1           20
# ...                           ...          ...
# 2011-12-09 12:23:00             1            2
# 2011-12-09 12:25:00             1            2
# 2011-12-09 12:31:00             1           21
# 2011-12-09 12:49:00             1            4
# 2011-12-09 12:50:00             1           15
#
#                                                                  Items
# InvoiceDate
# 2010-12-01 08:26:00  [WHITE HANGING HEART T-LIGHT HOLDER, WHITE MET...
# 2010-12-01 08:28:00  [HAND WARMER UNION JACK, HAND WARMER RED POLKA...
# 2010-12-01 08:34:00  [ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHO...
# 2010-12-01 08:35:00                         [BATH BUILDING BLOCK WORD]
# ...

# %%
pip install apyori
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from apyori import apriori

# %%
transactions = data_new["Items"].tolist()  ## Convert dataframe in to list
transactions
# Out:
# [array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#         'CREAM CUPID HEARTS COAT HANGER',
#         'KNITTED UNION FLAG HOT WATER BOTTLE',
#         'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES',
#         'GLASS STAR FROSTED T-LIGHT HOLDER'], dtype=object),
#  array(['HAND WARMER UNION JACK', 'HAND WARMER RED POLKA DOT'],
#        dtype=object),
#  array(['ASSORTED COLOUR BIRD ORNAMENT', "POPPY'S PLAYHOUSE BEDROOM ",
#         "POPPY'S PLAYHOUSE KITCHEN", 'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#         'IVORY KNITTED MUG COSY ', 'BOX OF 6 ASSORTED COLOUR TEASPOONS',
#         'BOX OF VINTAGE JIGSAW BLOCKS ', 'BOX OF VINTAGE ALPHABET BLOCKS',
#         'HOME BUILDING BLOCK WORD', 'LOVE BUILDING BLOCK WORD',
#         'RECIPE BOX WITH METAL HEART', 'DOORMAT NEW ENGLAND',
#         'JAM MAKING SET WITH JARS', 'RED COAT RACK PARIS FASHION',
#         'YELLOW COAT RACK PARIS FASHION', 'BLUE COAT RACK PARIS FASHION'],
#        dtype=object),
# ...

# %%
rules = apriori(transactions = transactions,min_support = 0.000020,min_confidence = 0.01,min_lift = 3,min_length = 2,max_length = 2)
results = list(rules)
results
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Input In [22], in <cell line: 2>()
#       1 rules = apriori(transactions = transactions,min_support = 0.000020,min_confidence = 0.01,min_lift = 3,min_length = 2,max_length = 2)
# ----> 2 results = list(rules)
#       3 results
#
# File ~\anaconda3\lib\site-packages\apyori.py:286, in apriori(transactions, **kwargs)
#     285 # Calculate ordered stats.
# --> 286 for support_record in support_records:
#     287     ordered_statistics = list(
#     288         _filter_ordered_statistics(
#     289             _gen_ordered_statistics(transaction_manager, support_record),
#    (...)
#     292         )
#     293     )
#
# File ~\anaconda3\lib\site-packages\apyori.py:199, in gen_support_records(transaction_manager, min_support, **kwargs)
#     198     break
# ...
