# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("D:/Datasets/world_data.csv")
data
# Out:
#       Unnamed: 0       artist_name                                track_name  \
# 0              0       Post Malone                                   Circles
# 1              1      Travis Scott                       HIGHEST IN THE ROOM
# 2              2        Juice WRLD  Bandit (with YoungBoy Never Broke Again)
# 3              3    Arizona Zervas                                   ROXANNE
# 4              4      Selena Gomez                       Lose You To Love Me
# ...          ...               ...                                       ...
# 9315        9315          Griselda                       Cruiser Weight Coke
# 9316        9316        Koe Wetzel                                 Powerball
# 9317        9317        Miky Woodz                             Forever Happy
# 9318        9318             Bazzi                              Live Forever
# 9319        9319  Alyssa Stanfield                                     Woman
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %% [markdown]
# Clustering to find a relation between Popularity of a song and danceability.

# %%
plt.scatter(data["popularity"],data["danceability"])
plt.xlabel("popularity")
plt.ylabel("danceability")
# Out:
# Text(0, 0.5, 'danceability')

# %%
km = KMeans(n_clusters = 3)
y_predicted = km.fit_predict(data[["popularity","danceability"]])
y_predicted
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %%
data["cluster"] = y_predicted
data.head()
# Out:
#    Unnamed: 0     artist_name                                track_name  \
# 0           0     Post Malone                                   Circles
# 1           1    Travis Scott                       HIGHEST IN THE ROOM
# 2           2      Juice WRLD  Bandit (with YoungBoy Never Broke Again)
# 3           3  Arizona Zervas                                   ROXANNE
# 4           4    Selena Gomez                       Lose You To Love Me
#
#                  track_id  popularity  danceability  energy  key  loudness  \
# 0  21jGcNKet2qwijlDFuPiPb          99         0.695   0.762    0    -3.497
# 1  3eekarcy7kvN4yt5ZFzltW          98         0.598   0.427    7    -8.764
# 2  6Gg1gjgKi2AK4e0qzsR7sd          93         0.474   0.631    5    -5.884
# 3  696DnlkuDOXcMAnKlTgXXK          97         0.621   0.601    6    -5.616
# 4  1HfMVBKM75vxSfsQ5VefZ5          98         0.505   0.340    4    -9.005
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
data["cluster"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9315    2
# 9316    2
# 9317    2
# 9318    2
# 9319    2
# Name: cluster, Length: 9320, dtype: int32>

# %%
km.cluster_centers_
# Out:
# array([[73.47154134,  0.64837748],
#        [ 7.20269058,  0.40666543],
#        [59.66026052,  0.61615035]])

# %%
data1 = data[data.cluster==0]
data2 = data[data.cluster==1]
data3 = data[data.cluster==2]
plt.scatter(data1["popularity"],data1["danceability"],color = "green")
plt.scatter(data2["popularity"],data2["danceability"],color = "red")
plt.scatter(data3["popularity"],data3["danceability"],color = "blue")
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color = "purple",marker="*",label="centroid")
plt.xlabel("popularity")
plt.ylabel("danceability")
plt.legend()

# %%
scaler = MinMaxScaler()
scaler.fit(data[["popularity"]])
data["popularity"]=scaler.transform(data[["popularity"]])
scaler.fit(data[["danceability"]])
data["danceability"]=scaler.transform(data[["danceability"]])

# %%
plt.scatter(data["popularity"],data["danceability"])

# %%
km = KMeans(n_clusters = 3)
y_predicted = km.fit_predict(data[["popularity","danceability"]])
y_predicted
# Out:
# array([0, 0, 2, ..., 2, 2, 2])

# %%
data["cluster"] = y_predicted
data.head()
# Out:
#    Unnamed: 0     artist_name                                track_name  \
# 0           0     Post Malone                                   Circles
# 1           1    Travis Scott                       HIGHEST IN THE ROOM
# 2           2      Juice WRLD  Bandit (with YoungBoy Never Broke Again)
# 3           3  Arizona Zervas                                   ROXANNE
# 4           4    Selena Gomez                       Lose You To Love Me
#
#                  track_id  popularity  danceability  energy  key  loudness  \
# 0  21jGcNKet2qwijlDFuPiPb        0.99      0.708461   0.762    0    -3.497
# 1  3eekarcy7kvN4yt5ZFzltW        0.98      0.609582   0.427    7    -8.764
# 2  6Gg1gjgKi2AK4e0qzsR7sd        0.93      0.483180   0.631    5    -5.884
# 3  696DnlkuDOXcMAnKlTgXXK        0.97      0.633028   0.601    6    -5.616
# 4  1HfMVBKM75vxSfsQ5VefZ5        0.98      0.514781   0.340    4    -9.005
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
km.cluster_centers_
# Out:
# array([[0.64618129, 0.7559854 ],
#        [0.06965079, 0.40764961],
#        [0.63535152, 0.44054661]])

# %%
data1 = data[data.cluster==0]
data2 = data[data.cluster==1]
data3 = data[data.cluster==2]
plt.scatter(data1["popularity"],data1["danceability"],color = "green")
plt.scatter(data2["popularity"],data2["danceability"],color = "red")
plt.scatter(data3["popularity"],data3["danceability"],color = "blue")
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color = "purple",marker="*",label="centroid")
plt.xlabel("popularity")
plt.ylabel("danceability")
plt.legend()

# %%
el=[]
k_range = range(1,20)
for k in k_range:
    km = KMeans(n_clusters=k)
    km.fit(data[["popularity","danceability"]])
    el.append(km.inertia_)

# %%
 plt.plot(k_range,el)

# %%
data1
# Out:
#       Unnamed: 0     artist_name                         track_name  \
# 0              0     Post Malone                            Circles
# 1              1    Travis Scott                HIGHEST IN THE ROOM
# 3              3  Arizona Zervas                            ROXANNE
# 5              5   Billie Eilish                everything i wanted
# 6              6       blackbear                    hot girl bummer
# ...          ...             ...                                ...
# 9311        9311   Phum Viphurit                     Hello, Anxiety
# 9312        9312  Chase Atlantic                                HER
# 9313        9313           Tekno                           Skeletun
# 9314        9314   Lucas & Steve  Say Something - RetroVision Remix
# 9315        9315        Griselda                Cruiser Weight Coke
#
#                     track_id  popularity  danceability  energy  key  loudness  \
# ...

# %%
data2
# Out:
#       Unnamed: 0    artist_name  \
# 202          202     Juice WRLD
# 321          321  Justin Bieber
# 322          322  Justin Bieber
# 323          323  Justin Bieber
# 324          324  Justin Bieber
# ...          ...            ...
# 9142        9142     Aloe Blacc
# 9143        9143     Aloe Blacc
# 9145        9145     Aloe Blacc
# 9146        9146     Aloe Blacc
# 9147        9147     Aloe Blacc
#
#                                              track_name  \
# 202                Let Me Know (I Wonder Why Freestyle)
# 321                                           Mistletoe
# 322   The Christmas Song (Chestnuts Roasting On An O...
# 323                                      Christmas Love
# 324     All I Want For Christmas Is You (SuperFestive!)
# ...                                                 ...
# 9142                                Mi Burrito Sabanero
# 9143                            The Mrs Saved Christmas
# 9145                                       At Christmas
# ...

# %%
data3
# Out:
#       Unnamed: 0       artist_name  \
# 2              2        Juice WRLD
# 4              4      Selena Gomez
# 10            10     Lewis Capaldi
# 12            12        The Weeknd
# 18            18       Post Malone
# ...          ...               ...
# 9308        9308   The Band CAMINO
# 9316        9316        Koe Wetzel
# 9317        9317        Miky Woodz
# 9318        9318             Bazzi
# 9319        9319  Alyssa Stanfield
#
#                                              track_name  \
# 2              Bandit (with YoungBoy Never Broke Again)
# 4                                   Lose You To Love Me
# 10                                    Someone You Loved
# 12                                            Heartless
# 18    Take What You Want (feat. Ozzy Osbourne & Trav...
# ...                                                 ...
# 9308                            Something To Hold On To
# 9316                                          Powerball
# ...
